# %% [markdown]
# <a href="https://colab.research.google.com/github/CabralRenan/Algoritimo2/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#numpy biblioteca para manipulaçao matematica
import numpy as np
#pandas lib para manipulaçao de dados
import pandas as pd

# %%
lista = [7,9,13,2,8]

# %%
print(lista)
# Out:
# [7, 9, 13, 2, 8]

# %%
lista2 = 2* lista

# %%
print(lista2)
# Out:
# [7, 9, 13, 2, 8, 7, 9, 13, 2, 8]

# %%
lista3 = np.array(lista)*2

# %%
print(lista3)
# Out:
# [14 18 26  4 16]

# %%
def soma(a, b):
  return a + b

# %%
w = soma(7,9)

# %%
w
# Out:
# 16
